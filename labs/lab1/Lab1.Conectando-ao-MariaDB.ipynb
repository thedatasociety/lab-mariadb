-- %% [markdown]
-- # Conectando ao Maria DB

-- %% [markdown]
-- Usando um kernel mais prático: https://github.com/MariaDB/mariadb_kernel/blob/master/binder/try_it_out.ipynb .
--
-- Este ambiente já possui uma instãncia do MariaDB em execução.

-- %%
select version();
-- Out:
-- <html><body><table border="1"><tr><th style="text-align:left;white-space:pre">version()</th></tr><tr><td style="text-align:left;white-space:pre">10.4.20-MariaDB</td></tr></table></body></html>

-- %% [markdown]
-- Sobre essa versão: https://mariadb.com/kb/en/changes-improvements-in-mariadb-104/

-- %%
SHOW VARIABLES LIKE "%version%";
-- Out:
-- <html><body><table border="1"><tr><th style="text-align:left;white-space:pre">Variable_name</th><th style="text-align:left;white-space:pre">Value</th></tr><tr><td style="text-align:left;white-space:pre">in_predicate_conversion_threshold</td><td style="text-align:left;white-space:pre">1000</td></tr><tr><td style="text-align:left;white-space:pre">innodb_version</td><td style="text-align:left;white-space:pre">10.4.20</td></tr><tr><td style="text-align:left;white-space:pre">protocol_version</td><td style="text-align:left;white-space:pre">10</td></tr><tr><td style="text-align:left;white-space:pre">slave_type_conversions</td><td style="text-align:left;white-space:pre"></td></tr><tr><td style="text-align:left;white-space:pre">system_versioning_alter_history</td><td style="text-align:left;white-space:pre">ERROR</td></tr><tr><td style="text-align:left;white-space:pre">system_versioning_asof</td><td style="text-align:left;white-space:pre">DEFAULT</td></tr><tr><td style="text-align:left;white-
-- ...

-- %%
show databases;
-- Out:
-- <html><body><table border="1"><tr><th style="text-align:left;white-space:pre">Database</th></tr><tr><td style="text-align:left;white-space:pre">information_schema</td></tr><tr><td style="text-align:left;white-space:pre">movielens</td></tr><tr><td style="text-align:left;white-space:pre">taxis</td></tr></table></body></html>

-- %%
create database if not exists test;
-- Out:
-- Query OK

-- %%
show databases;
-- Out:
-- <html><body><table border="1"><tr><th style="text-align:left;white-space:pre">Database</th></tr><tr><td style="text-align:left;white-space:pre">information_schema</td></tr><tr><td style="text-align:left;white-space:pre">tests</td></tr></table></body></html>

-- %%
select * from information_schema.tables where engine <> 'PERFORMANCE_SCHEMA' limit 200;
-- Out:
-- <html><body><table border="1"><tr><th style="text-align:left;white-space:pre">TABLE_CATALOG</th><th style="text-align:left;white-space:pre">TABLE_SCHEMA</th><th style="text-align:left;white-space:pre">TABLE_NAME</th><th style="text-align:left;white-space:pre">TABLE_TYPE</th><th style="text-align:left;white-space:pre">ENGINE</th><th style="text-align:left;white-space:pre">VERSION</th><th style="text-align:left;white-space:pre">ROW_FORMAT</th><th style="text-align:left;white-space:pre">TABLE_ROWS</th><th style="text-align:left;white-space:pre">AVG_ROW_LENGTH</th><th style="text-align:left;white-space:pre">DATA_LENGTH</th><th style="text-align:left;white-space:pre">MAX_DATA_LENGTH</th><th style="text-align:left;white-space:pre">INDEX_LENGTH</th><th style="text-align:left;white-space:pre">DATA_FREE</th><th style="text-align:left;white-space:pre">AUTO_INCREMENT</th><th style="text-align:left;white-space:pre">CREATE_TIME</th><th style="text-align:left;white-space:pre">UPDATE_TIME</th><th 
-- ...
